# %% [markdown]
# <a href="https://colab.research.google.com/github/Zdestrion/ML_pvt_repo/blob/master/Semi_def_NN_Mini_BooNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Utilizzo di una semplice Neural Network per la classificazione

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Si importano anzitutto le librerie utili:

# %%
#Various basic imports and libraries

import tensorflow as tf
from tensorflow import keras

import numpy as np

import pandas as pd
import time
import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
#from mpl_toolkits.axes_grid1 import make_axes_locatable

from scipy import stats 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

warnings.filterwarnings('ignore')

# %% [markdown]
# Si importa il dataset da Drive, utilizzando Pandas per una rappresentazione dei dati più comoda. \\
# Si assegna una colonna di feature finale adibita alle labels, basata sulle informazioni che si hanno sui dati (primi 36499 di segnale, restanti di background).

# %%
df_old = pd.read_fwf('/content/drive/My Drive/Colab Notebooks/dataset/MiniBooNE_PID.txt')

# %%
df_old["signal"]=0
df_old.iloc[0:36499,50]=1
df_old.iloc[36499:,50]=0
df_old
# Out:
#         36499 93565  Unnamed: 1  Unnamed: 2  ...  Unnamed: 48  Unnamed: 49  signal
# 0           2.59413    0.468803     20.6916  ...     0.071769     0.245996       1
# 1           3.86388    0.645781     18.1375  ...     0.333613     0.230621       1
# 2           3.38584    1.197140     36.0807  ...     0.255512     0.180901       1
# 3           4.28524    0.510155    674.2010  ...     0.473081     0.258990       1
# 4           5.93662    0.832993     59.8796  ...     1.924990     0.253893       1
# ...             ...         ...         ...  ...          ...          ...     ...
# 130059      4.80718    1.451020    174.6920  ...     3.219320     0.299487       0
# 130060      5.00527    1.501860    129.9270  ...     1.778180     0.258058       0
# 130061      3.10842    2.178140     56.3651  ...     0.730342     0.152876       0
# 130062      5.44560    1.845700    103.4630  ...     0.819867     0.210619       0
# 130063      4.55062    1.341740     80.0887  ...     0.742709     0.276477       0
#
# [130064 rows x 51 columns]

# %% [markdown]
# Per fare in modo di prendere uno splitting il più casuale possibile, si applica uno shuffle alle righe.

# %%
#Shuffling
df = df_old.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#         36499 93565  Unnamed: 1  Unnamed: 2  ...  Unnamed: 48  Unnamed: 49  signal
# 0           3.23910    0.650082    73.07690  ...     0.249577     0.180645       1
# 1           6.99265    1.555350   115.64500  ...     7.928000     0.243108       0
# 2           4.70259    2.745000     8.31279  ...     1.309860     0.264129       0
# 3           5.51759    1.647710   117.42000  ...     3.150770     0.295350       0
# 4           5.24549    1.410260   156.95900  ...    -0.439253     0.199084       0
# ...             ...         ...         ...  ...          ...          ...     ...
# 130059      4.17954    0.466373    69.36150  ...     0.483639     0.235735       1
# 130060      4.01851    1.440660     6.52664  ...     0.914416     0.266890       1
# 130061      4.43895    1.348580   546.93200  ...     1.767240     0.247891       0
# 130062      5.67454    1.770470   141.70300  ...     1.302770     0.219139       0
# 130063      5.41076    1.021220    99.59660  ...    -0.082993     0.187979       0
#
# [130064 rows x 51 columns]

# %% [markdown]
# Si mantiene un dataframe comprensivo di outliers e se ne modifica un secondo escludendo questi ultimi secondo un criterio "permissivo", eliminando semplicemente i dati oltre le 3 $\sigma$.

# %%
df_outliers = df

# %%
z = np.abs(stats.zscore(df))
df = df[(z < 3).all(axis=1)]
df
# Out:
#         36499 93565  Unnamed: 1  Unnamed: 2  ...  Unnamed: 48  Unnamed: 49  signal
# 0           3.23910    0.650082    73.07690  ...     0.249577     0.180645       1
# 1           6.99265    1.555350   115.64500  ...     7.928000     0.243108       0
# 2           4.70259    2.745000     8.31279  ...     1.309860     0.264129       0
# 3           5.51759    1.647710   117.42000  ...     3.150770     0.295350       0
# 4           5.24549    1.410260   156.95900  ...    -0.439253     0.199084       0
# ...             ...         ...         ...  ...          ...          ...     ...
# 130059      4.17954    0.466373    69.36150  ...     0.483639     0.235735       1
# 130060      4.01851    1.440660     6.52664  ...     0.914416     0.266890       1
# 130061      4.43895    1.348580   546.93200  ...     1.767240     0.247891       0
# 130062      5.67454    1.770470   141.70300  ...     1.302770     0.219139       0
# 130063      5.41076    1.021220    99.59660  ...    -0.082993     0.187979       0
#
# [123480 rows x 51 columns]

# %% [markdown]
# Si creano dunque i vettori di dati e label per entrambi i dataframe, normalizzando i dati con $\textit{MinMaxScaler}$.

# %%
labels = df["signal"].values

data = df.drop(labels='signal', axis=1)
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

print(labels.shape)
print(data.shape)
# Out:
# (123480,)
# (123480, 50)

# %%
labels_out = df_outliers["signal"].values

data_out = df_outliers.drop(labels='signal', axis=1)
data_out = scaler.fit_transform(data_out)

print(labels_out.shape)
print(data_out.shape)
# Out:
# (130064,)
# (130064, 50)

# %%
data = data.astype('float32')
labels = labels.astype('float32')
data_out = data_out.astype('float32')
labels_out = labels_out.astype('float32')

# %%
#Splitting
train_to_test_ratio=0.8

X_train,X_test,Y_train_nc,Y_test_nc=train_test_split(data,labels,train_size=train_to_test_ratio)
#Y_train = keras.utils.to_categorical(Y_train_nc)
#Y_test = keras.utils.to_categorical(Y_test_nc)
print(X_train.shape)
print(X_test.shape)
print(Y_train_nc.shape)
print(Y_test_nc.shape)
# Out:
# (98784, 50)
# (24696, 50)
# (98784,)
# (24696,)

# %% [markdown]
# Si definisce dunque una funzione che crei il modello di Rete Neurale desiderato. Si decide di optare per un modello semplice, che consta di tre blocchi densi, ciascuno costituito da:
# * layer denso (256 units);
# * layer di Batch Normalization;
# * layer di attivazione ReLU;
# * layer di Dropout (rate rispettivamente 0.5, 0.2, 0.2).
#
# Dopo i tre blocchi densi vi è un layer denso ad una singola unità, con attivazione sigmoide, utile al fine della classificazione che si vuole operare (background/signal, 0/1). \\
# Il numero di units dei layer densi e il rate dei layer di dropout sono stati tunati in precedenza mediante l'utilizzo di HyperBand, messo a disposizione da Keras. L'idea alla base di un rate di dropout maggiore nel primo blocco è funzionale alla riduzione dell'overfitting. A questo fine e per uno smoothing della loss function e della accuracy vengono utilizzati i layer di Batch Normalization e (come si vedrà in seguito) il decadimento esponenziale del learning rate.

# %%
#Model definition (functional)
def create_model():
  inputs = keras.Input(shape=(50))
  x = inputs

  x = keras.layers.Dense(256, name='Dense_1')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(name='ReLU_dense_1')(x)
  x = keras.layers.Dropout(rate=0.5)(x)

  x = keras.layers.Dense(256, name='Dense_2')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(name='ReLU_dense_2')(x)
  x = keras.layers.Dropout(rate=0.2)(x)

  x = keras.layers.Dense(256, name='Dense_3')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(name='ReLU_dense_3')(x)
  x = keras.layers.Dropout(rate=0.2)(x)
  
  outputs = keras.layers.Dense(1, activation='sigmoid', name='Output')(x)

  model = keras.Model(inputs=inputs, outputs=outputs, name='MiniBooNE_CNN')
  return model

model = create_model()  
model.summary()

keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "MiniBooNE_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# Dense_1 (Dense)              (None, 256)               13056
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# ReLU_dense_1 (ReLU)          (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# ReLU_dense_2 (ReLU)          (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# ReLU_dense_3 (ReLU)          (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 257
# =================================================================
# Total params: 147,969
# Trainable params: 146,433
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# Per questo problema in particolare si è riteso opportuno utilizzare la $\textit{binary crossentropy}$ come loss function e utilizzare come metriche del modello l'accuracy e la AUC (Area Under Curve). \\
# Si prova il training con un learning rate con decadimento esponenziale, ottimizzato tramite Adam:

# %%
LR_ST=(1e-2)*2
OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=LR_ST)
model= create_model()
EAGERLY = False
auc = keras.metrics.AUC()

model.compile(optimizer=OPTIMIZER,
              loss='binary_crossentropy',
              metrics=['accuracy', auc],
              run_eagerly=EAGERLY)

# %% [markdown]
# Si opta dunque per un decadimento esponenziale $e^{0.035*(10-epoch)}$, in modo che il learning rate non decada troppo bruscamente e la rete continui ad imparare adeguatamente prima di arrivare a saturazione. \\
# Il rate di decadimento e l'epoca dalla quale iniziare a far decadere il learning rate sono stati scelti in modo fossero adeguati al numero di epoche totali scelto (100) e all'architettura della rete. \\
# Con un numero di epoche maggiori (es: 1000) sarebbe stato possibile scegliere dropout maggiore e learning rate minore, ad esempio. ??????????????????????????????????????????????????????????????????????????????????????????????????????????

# %%
def lr_decay(epoch):
  if epoch < 10:
    return LR_ST
  else:
    return LR_ST * tf.math.exp(0.035 * (10 - epoch))

lr_scheduler = keras.callbacks.LearningRateScheduler(lr_decay)

model_checkpoint = keras.callbacks.ModelCheckpoint(
        filepath = 'best_epoch_constant',
        verbose = 0,
        save_weights_only = True, 
        save_freq = 'epoch',
        save_best_only = True,
        mode ='min')

callbacks = [ lr_scheduler, model_checkpoint ]

start_time = time.time()

history = model.fit(X_train, Y_train_nc, epochs=100, batch_size=128,
                    validation_split=0.2, shuffle=True, verbose=2,
                    callbacks=callbacks)

print("\n\nTime to train the neural network:", time.time()-start_time)
# Out:
# Epoch 1/100
# 618/618 - 4s - loss: 0.2050 - accuracy: 0.9167 - auc_5: 0.9654 - val_loss: 0.2335 - val_accuracy: 0.8874 - val_auc_5: 0.9725 - lr: 0.0200
# Epoch 2/100
# 618/618 - 4s - loss: 0.1783 - accuracy: 0.9286 - auc_5: 0.9737 - val_loss: 0.1964 - val_accuracy: 0.9084 - val_auc_5: 0.9786 - lr: 0.0200
# Epoch 3/100
# 618/618 - 4s - loss: 0.1726 - accuracy: 0.9310 - auc_5: 0.9753 - val_loss: 0.1925 - val_accuracy: 0.9130 - val_auc_5: 0.9781 - lr: 0.0200
# Epoch 4/100
# 618/618 - 4s - loss: 0.1674 - accuracy: 0.9332 - auc_5: 0.9767 - val_loss: 0.1596 - val_accuracy: 0.9362 - val_auc_5: 0.9804 - lr: 0.0200
# Epoch 5/100
# 618/618 - 4s - loss: 0.1648 - accuracy: 0.9338 - auc_5: 0.9774 - val_loss: 0.1622 - val_accuracy: 0.9363 - val_auc_5: 0.9799 - lr: 0.0200
# Epoch 6/100
# 618/618 - 4s - loss: 0.1630 - accuracy: 0.9347 - auc_5: 0.9780 - val_loss: 0.1961 - val_accuracy: 0.9156 - val_auc_5: 0.9773 - lr: 0.0200
# Epoch 7/100
# 618/618 - 4s - loss: 0.1597 - accuracy: 0.9357 - auc_5: 0.9787 - val_loss: 0.1600 - val_accuracy: 0.9381 - val_auc_5: 0.9816 - lr: 0.0200
# Epoch 8/100
# 618/618 - 4s - loss: 0.1588 - accuracy: 0.9363 - auc_5: 0.9788 - val_loss: 0.1569 - val_accuracy: 0.9364 - val_auc_5: 0.9808 - lr: 0.0200
# Epoch 9/100
# 618/618 - 4s - loss: 0.1571 - accuracy: 0.9364 - auc_5: 0.9795 - val_loss: 0.1445 - val_accuracy: 0.9429 - val_auc_5: 0.9831 - lr: 0.0200
# Epoch 10/100
# 618/618 - 4s - loss: 0.1566 - accuracy: 0.9372 - auc_5: 0.9796 - val_loss: 0.1525 - val_accuracy: 0.9399 - val_auc_5: 0.9814 - lr: 0.0200
# Epoch 11/100
# 618/618 - 4s - loss: 0.1568 - accuracy: 0.9375 - auc_5: 0.9794 - val_loss: 0.1489 - val_accuracy: 0.9419 - val_auc_5: 0.9826 - lr: 0.0200
# Epoch 12/100
# 618/618 - 4s - loss: 0.1538 - accuracy: 0.9389 - auc_5: 0.9803 - val_loss: 0.1421 - val_accuracy: 0.9434 - val_auc_5: 0.9833 - lr: 0.0193
# Epoch 13/100
# 618/618 - 4s - loss: 0.1521 - accuracy: 0.9385 - auc_5: 0.9807 - val_loss: 0.1373 - val_accuracy: 0.9458 - val_auc_5: 0.9841 - lr: 0.0186
# Epoch 14/100
# 618/618 - 4s - loss: 0.1508 - accuracy: 0.9386 - auc_5: 0.9811 - val_loss: 0.1429 - val_accuracy: 0.9455 - val_auc_5: 0.9846 - lr: 0.0180
# Epoch 15/100
# 618/618 - 4s - loss: 0.1488 - accuracy: 0.9402 - auc_5: 0.9813 - val_loss: 0.1448 - val_accuracy: 0.9431 - val_auc_5: 0.9840 - lr: 0.0174
# Epoch 16/100
# 618/618 - 4s - loss: 0.1497 - accuracy: 0.9406 - auc_5: 0.9812 - val_loss: 0.1434 - val_accuracy: 0.9451 - val_auc_5: 0.9848 - lr: 0.0168
# Epoch 17/100
# 618/618 - 4s - loss: 0.1477 - accuracy: 0.9408 - auc_5: 0.9817 - val_loss: 0.1561 - val_accuracy: 0.9341 - val_auc_5: 0.9837 - lr: 0.0162
# Epoch 18/100
# 618/618 - 4s - loss: 0.1465 - accuracy: 0.9414 - auc_5: 0.9819 - val_loss: 0.1367 - val_accuracy: 0.9452 - val_auc_5: 0.9840 - lr: 0.0157
# Epoch 19/100
# 618/618 - 4s - loss: 0.1444 - accuracy: 0.9423 - auc_5: 0.9824 - val_loss: 0.1342 - val_accuracy: 0.9452 - val_auc_5: 0.9849 - lr: 0.0151
# Epoch 20/100
# 618/618 - 4s - loss: 0.1448 - accuracy: 0.9415 - auc_5: 0.9824 - val_loss: 0.1499 - val_accuracy: 0.9365 - val_auc_5: 0.9840 - lr: 0.0146
# Epoch 21/100
# 618/618 - 4s - loss: 0.1424 - accuracy: 0.9433 - auc_5: 0.9829 - val_loss: 0.1357 - val_accuracy: 0.9455 - val_auc_5: 0.9852 - lr: 0.0141
# Epoch 22/100
# 618/618 - 4s - loss: 0.1417 - accuracy: 0.9437 - auc_5: 0.9830 - val_loss: 0.1358 - val_accuracy: 0.9458 - val_auc_5: 0.9855 - lr: 0.0136
# Epoch 23/100
# 618/618 - 4s - loss: 0.1410 - accuracy: 0.9435 - auc_5: 0.9834 - val_loss: 0.1337 - val_accuracy: 0.9454 - val_auc_5: 0.9851 - lr: 0.0131
# Epoch 24/100
# 618/618 - 4s - loss: 0.1395 - accuracy: 0.9443 - auc_5: 0.9837 - val_loss: 0.1323 - val_accuracy: 0.9474 - val_auc_5: 0.9851 - lr: 0.0127
# Epoch 25/100
# 618/618 - 4s - loss: 0.1384 - accuracy: 0.9437 - auc_5: 0.9840 - val_loss: 0.1336 - val_accuracy: 0.9467 - val_auc_5: 0.9857 - lr: 0.0123
# Epoch 26/100
# 618/618 - 4s - loss: 0.1377 - accuracy: 0.9451 - auc_5: 0.9840 - val_loss: 0.1328 - val_accuracy: 0.9471 - val_auc_5: 0.9853 - lr: 0.0118
# Epoch 27/100
# 618/618 - 4s - loss: 0.1363 - accuracy: 0.9449 - auc_5: 0.9845 - val_loss: 0.1315 - val_accuracy: 0.9477 - val_auc_5: 0.9861 - lr: 0.0114
# Epoch 28/100
# 618/618 - 4s - loss: 0.1345 - accuracy: 0.9463 - auc_5: 0.9848 - val_loss: 0.1304 - val_accuracy: 0.9478 - val_auc_5: 0.9857 - lr: 0.0110
# Epoch 29/100
# 618/618 - 3s - loss: 0.1346 - accuracy: 0.9457 - auc_5: 0.9848 - val_loss: 0.1405 - val_accuracy: 0.9451 - val_auc_5: 0.9853 - lr: 0.0107
# Epoch 30/100
# 618/618 - 4s - loss: 0.1335 - accuracy: 0.9467 - auc_5: 0.9848 - val_loss: 0.1308 - val_accuracy: 0.9490 - val_auc_5: 0.9852 - lr: 0.0103
# Epoch 31/100
# 618/618 - 4s - loss: 0.1348 - accuracy: 0.9459 - auc_5: 0.9845 - val_loss: 0.1289 - val_accuracy: 0.9484 - val_auc_5: 0.9860 - lr: 0.0099
# Epoch 32/100
# 618/618 - 4s - loss: 0.1339 - accuracy: 0.9464 - auc_5: 0.9849 - val_loss: 0.1289 - val_accuracy: 0.9489 - val_auc_5: 0.9859 - lr: 0.0096
# Epoch 33/100
# 618/618 - 4s - loss: 0.1330 - accuracy: 0.9468 - auc_5: 0.9850 - val_loss: 0.1347 - val_accuracy: 0.9458 - val_auc_5: 0.9854 - lr: 0.0093
# Epoch 34/100
# 618/618 - 4s - loss: 0.1320 - accuracy: 0.9469 - auc_5: 0.9851 - val_loss: 0.1297 - val_accuracy: 0.9474 - val_auc_5: 0.9863 - lr: 0.0089
# Epoch 35/100
# 618/618 - 4s - loss: 0.1317 - accuracy: 0.9469 - auc_5: 0.9853 - val_loss: 0.1298 - val_accuracy: 0.9479 - val_auc_5: 0.9863 - lr: 0.0086
# Epoch 36/100
# 618/618 - 4s - loss: 0.1299 - accuracy: 0.9482 - auc_5: 0.9858 - val_loss: 0.1294 - val_accuracy: 0.9491 - val_auc_5: 0.9859 - lr: 0.0083
# Epoch 37/100
# 618/618 - 4s - loss: 0.1299 - accuracy: 0.9479 - auc_5: 0.9857 - val_loss: 0.1291 - val_accuracy: 0.9489 - val_auc_5: 0.9863 - lr: 0.0081
# Epoch 38/100
# 618/618 - 4s - loss: 0.1314 - accuracy: 0.9476 - auc_5: 0.9853 - val_loss: 0.1280 - val_accuracy: 0.9498 - val_auc_5: 0.9863 - lr: 0.0078
# Epoch 39/100
# 618/618 - 4s - loss: 0.1289 - accuracy: 0.9489 - auc_5: 0.9859 - val_loss: 0.1292 - val_accuracy: 0.9489 - val_auc_5: 0.9861 - lr: 0.0075
# Epoch 40/100
# 618/618 - 4s - loss: 0.1283 - accuracy: 0.9483 - auc_5: 0.9861 - val_loss: 0.1276 - val_accuracy: 0.9494 - val_auc_5: 0.9863 - lr: 0.0072
# Epoch 41/100
# 618/618 - 4s - loss: 0.1282 - accuracy: 0.9479 - auc_5: 0.9861 - val_loss: 0.1271 - val_accuracy: 0.9499 - val_auc_5: 0.9861 - lr: 0.0070
# Epoch 42/100
# 618/618 - 4s - loss: 0.1273 - accuracy: 0.9487 - auc_5: 0.9862 - val_loss: 0.1272 - val_accuracy: 0.9497 - val_auc_5: 0.9863 - lr: 0.0068
# Epoch 43/100
# 618/618 - 4s - loss: 0.1272 - accuracy: 0.9489 - auc_5: 0.9863 - val_loss: 0.1296 - val_accuracy: 0.9488 - val_auc_5: 0.9859 - lr: 0.0065
# Epoch 44/100
# 618/618 - 4s - loss: 0.1272 - accuracy: 0.9490 - auc_5: 0.9863 - val_loss: 0.1271 - val_accuracy: 0.9507 - val_auc_5: 0.9863 - lr: 0.0063
# Epoch 45/100
# 618/618 - 4s - loss: 0.1266 - accuracy: 0.9493 - auc_5: 0.9865 - val_loss: 0.1272 - val_accuracy: 0.9496 - val_auc_5: 0.9862 - lr: 0.0061
# Epoch 46/100
# 618/618 - 3s - loss: 0.1255 - accuracy: 0.9494 - auc_5: 0.9866 - val_loss: 0.1293 - val_accuracy: 0.9493 - val_auc_5: 0.9855 - lr: 0.0059
# Epoch 47/100
# 618/618 - 4s - loss: 0.1258 - accuracy: 0.9491 - auc_5: 0.9866 - val_loss: 0.1260 - val_accuracy: 0.9513 - val_auc_5: 0.9865 - lr: 0.0057
# Epoch 48/100
# 618/618 - 3s - loss: 0.1257 - accuracy: 0.9501 - auc_5: 0.9867 - val_loss: 0.1273 - val_accuracy: 0.9503 - val_auc_5: 0.9862 - lr: 0.0055
# Epoch 49/100
# 618/618 - 3s - loss: 0.1242 - accuracy: 0.9501 - auc_5: 0.9869 - val_loss: 0.1264 - val_accuracy: 0.9508 - val_auc_5: 0.9864 - lr: 0.0053
# Epoch 50/100
# 618/618 - 4s - loss: 0.1227 - accuracy: 0.9510 - auc_5: 0.9871 - val_loss: 0.1274 - val_accuracy: 0.9498 - val_auc_5: 0.9864 - lr: 0.0051
# Epoch 51/100
# 618/618 - 3s - loss: 0.1237 - accuracy: 0.9506 - auc_5: 0.9869 - val_loss: 0.1262 - val_accuracy: 0.9501 - val_auc_5: 0.9865 - lr: 0.0049
# Epoch 52/100
# 618/618 - 4s - loss: 0.1231 - accuracy: 0.9503 - auc_5: 0.9872 - val_loss: 0.1268 - val_accuracy: 0.9505 - val_auc_5: 0.9865 - lr: 0.0048
# Epoch 53/100
# 618/618 - 3s - loss: 0.1238 - accuracy: 0.9505 - auc_5: 0.9870 - val_loss: 0.1262 - val_accuracy: 0.9510 - val_auc_5: 0.9866 - lr: 0.0046
# Epoch 54/100
# 618/618 - 4s - loss: 0.1225 - accuracy: 0.9508 - auc_5: 0.9872 - val_loss: 0.1275 - val_accuracy: 0.9502 - val_auc_5: 0.9860 - lr: 0.0044
# Epoch 55/100
# 618/618 - 4s - loss: 0.1223 - accuracy: 0.9503 - auc_5: 0.9874 - val_loss: 0.1252 - val_accuracy: 0.9511 - val_auc_5: 0.9864 - lr: 0.0043
# Epoch 56/100
# 618/618 - 4s - loss: 0.1230 - accuracy: 0.9505 - auc_5: 0.9872 - val_loss: 0.1258 - val_accuracy: 0.9512 - val_auc_5: 0.9865 - lr: 0.0041
# Epoch 57/100
# 618/618 - 4s - loss: 0.1227 - accuracy: 0.9503 - auc_5: 0.9873 - val_loss: 0.1268 - val_accuracy: 0.9509 - val_auc_5: 0.9862 - lr: 0.0040
# Epoch 58/100
# 618/618 - 4s - loss: 0.1210 - accuracy: 0.9512 - auc_5: 0.9876 - val_loss: 0.1254 - val_accuracy: 0.9507 - val_auc_5: 0.9865 - lr: 0.0039
# Epoch 59/100
# 618/618 - 4s - loss: 0.1215 - accuracy: 0.9508 - auc_5: 0.9874 - val_loss: 0.1264 - val_accuracy: 0.9507 - val_auc_5: 0.9864 - lr: 0.0037
# Epoch 60/100
# 618/618 - 3s - loss: 0.1217 - accuracy: 0.9513 - auc_5: 0.9874 - val_loss: 0.1257 - val_accuracy: 0.9508 - val_auc_5: 0.9864 - lr: 0.0036
# Epoch 61/100
# 618/618 - 4s - loss: 0.1214 - accuracy: 0.9516 - auc_5: 0.9876 - val_loss: 0.1259 - val_accuracy: 0.9511 - val_auc_5: 0.9863 - lr: 0.0035
# Epoch 62/100
# 618/618 - 4s - loss: 0.1206 - accuracy: 0.9523 - auc_5: 0.9875 - val_loss: 0.1258 - val_accuracy: 0.9505 - val_auc_5: 0.9865 - lr: 0.0034
# Epoch 63/100
# 618/618 - 4s - loss: 0.1210 - accuracy: 0.9513 - auc_5: 0.9876 - val_loss: 0.1253 - val_accuracy: 0.9513 - val_auc_5: 0.9866 - lr: 0.0032
# Epoch 64/100
# 618/618 - 4s - loss: 0.1191 - accuracy: 0.9523 - auc_5: 0.9878 - val_loss: 0.1260 - val_accuracy: 0.9506 - val_auc_5: 0.9865 - lr: 0.0031
# Epoch 65/100
# 618/618 - 4s - loss: 0.1189 - accuracy: 0.9527 - auc_5: 0.9880 - val_loss: 0.1264 - val_accuracy: 0.9508 - val_auc_5: 0.9864 - lr: 0.0030
# Epoch 66/100
# 618/618 - 3s - loss: 0.1194 - accuracy: 0.9521 - auc_5: 0.9878 - val_loss: 0.1258 - val_accuracy: 0.9508 - val_auc_5: 0.9865 - lr: 0.0029
# Epoch 67/100
# 618/618 - 3s - loss: 0.1196 - accuracy: 0.9518 - auc_5: 0.9879 - val_loss: 0.1270 - val_accuracy: 0.9503 - val_auc_5: 0.9864 - lr: 0.0028
# Epoch 68/100
# 618/618 - 4s - loss: 0.1179 - accuracy: 0.9531 - auc_5: 0.9882 - val_loss: 0.1252 - val_accuracy: 0.9511 - val_auc_5: 0.9865 - lr: 0.0027
# Epoch 69/100
# 618/618 - 4s - loss: 0.1182 - accuracy: 0.9525 - auc_5: 0.9881 - val_loss: 0.1255 - val_accuracy: 0.9515 - val_auc_5: 0.9866 - lr: 0.0026
# Epoch 70/100
# 618/618 - 4s - loss: 0.1173 - accuracy: 0.9535 - auc_5: 0.9883 - val_loss: 0.1255 - val_accuracy: 0.9513 - val_auc_5: 0.9865 - lr: 0.0025
# Epoch 71/100
# 618/618 - 4s - loss: 0.1188 - accuracy: 0.9524 - auc_5: 0.9879 - val_loss: 0.1263 - val_accuracy: 0.9517 - val_auc_5: 0.9865 - lr: 0.0024
# Epoch 72/100
# 618/618 - 4s - loss: 0.1179 - accuracy: 0.9524 - auc_5: 0.9881 - val_loss: 0.1255 - val_accuracy: 0.9517 - val_auc_5: 0.9864 - lr: 0.0024
# Epoch 73/100
# 618/618 - 3s - loss: 0.1178 - accuracy: 0.9528 - auc_5: 0.9883 - val_loss: 0.1269 - val_accuracy: 0.9515 - val_auc_5: 0.9862 - lr: 0.0023
# Epoch 74/100
# 618/618 - 4s - loss: 0.1173 - accuracy: 0.9523 - auc_5: 0.9883 - val_loss: 0.1267 - val_accuracy: 0.9513 - val_auc_5: 0.9862 - lr: 0.0022
# Epoch 75/100
# 618/618 - 4s - loss: 0.1168 - accuracy: 0.9532 - auc_5: 0.9883 - val_loss: 0.1256 - val_accuracy: 0.9514 - val_auc_5: 0.9864 - lr: 0.0021
# Epoch 76/100
# 618/618 - 4s - loss: 0.1167 - accuracy: 0.9526 - auc_5: 0.9883 - val_loss: 0.1262 - val_accuracy: 0.9513 - val_auc_5: 0.9863 - lr: 0.0021
# Epoch 77/100
# 618/618 - 4s - loss: 0.1183 - accuracy: 0.9527 - auc_5: 0.9881 - val_loss: 0.1257 - val_accuracy: 0.9514 - val_auc_5: 0.9864 - lr: 0.0020
# Epoch 78/100
# 618/618 - 4s - loss: 0.1184 - accuracy: 0.9528 - auc_5: 0.9882 - val_loss: 0.1256 - val_accuracy: 0.9522 - val_auc_5: 0.9864 - lr: 0.0019
# Epoch 79/100
# 618/618 - 4s - loss: 0.1158 - accuracy: 0.9530 - auc_5: 0.9887 - val_loss: 0.1257 - val_accuracy: 0.9516 - val_auc_5: 0.9865 - lr: 0.0019
# Epoch 80/100
# 618/618 - 4s - loss: 0.1172 - accuracy: 0.9530 - auc_5: 0.9883 - val_loss: 0.1262 - val_accuracy: 0.9518 - val_auc_5: 0.9861 - lr: 0.0018
# Epoch 81/100
# 618/618 - 3s - loss: 0.1163 - accuracy: 0.9540 - auc_5: 0.9885 - val_loss: 0.1258 - val_accuracy: 0.9516 - val_auc_5: 0.9862 - lr: 0.0017
# Epoch 82/100
# 618/618 - 4s - loss: 0.1161 - accuracy: 0.9530 - auc_5: 0.9885 - val_loss: 0.1259 - val_accuracy: 0.9513 - val_auc_5: 0.9863 - lr: 0.0017
# Epoch 83/100
# 618/618 - 4s - loss: 0.1153 - accuracy: 0.9535 - auc_5: 0.9887 - val_loss: 0.1256 - val_accuracy: 0.9514 - val_auc_5: 0.9866 - lr: 0.0016
# Epoch 84/100
# 618/618 - 4s - loss: 0.1146 - accuracy: 0.9542 - auc_5: 0.9889 - val_loss: 0.1262 - val_accuracy: 0.9517 - val_auc_5: 0.9861 - lr: 0.0016
# Epoch 85/100
# 618/618 - 4s - loss: 0.1153 - accuracy: 0.9530 - auc_5: 0.9887 - val_loss: 0.1260 - val_accuracy: 0.9521 - val_auc_5: 0.9863 - lr: 0.0015
# Epoch 86/100
# 618/618 - 4s - loss: 0.1164 - accuracy: 0.9536 - auc_5: 0.9885 - val_loss: 0.1267 - val_accuracy: 0.9515 - val_auc_5: 0.9862 - lr: 0.0014
# Epoch 87/100
# 618/618 - 3s - loss: 0.1159 - accuracy: 0.9541 - auc_5: 0.9885 - val_loss: 0.1254 - val_accuracy: 0.9515 - val_auc_5: 0.9865 - lr: 0.0014
# Epoch 88/100
# 618/618 - 3s - loss: 0.1162 - accuracy: 0.9528 - auc_5: 0.9886 - val_loss: 0.1262 - val_accuracy: 0.9514 - val_auc_5: 0.9863 - lr: 0.0014
# Epoch 89/100
# 618/618 - 3s - loss: 0.1150 - accuracy: 0.9543 - auc_5: 0.9886 - val_loss: 0.1267 - val_accuracy: 0.9512 - val_auc_5: 0.9862 - lr: 0.0013
# Epoch 90/100
# 618/618 - 4s - loss: 0.1155 - accuracy: 0.9538 - auc_5: 0.9886 - val_loss: 0.1256 - val_accuracy: 0.9518 - val_auc_5: 0.9865 - lr: 0.0013
# Epoch 91/100
# 618/618 - 4s - loss: 0.1152 - accuracy: 0.9535 - auc_5: 0.9888 - val_loss: 0.1261 - val_accuracy: 0.9511 - val_auc_5: 0.9863 - lr: 0.0012
# Epoch 92/100
# 618/618 - 3s - loss: 0.1157 - accuracy: 0.9535 - auc_5: 0.9886 - val_loss: 0.1256 - val_accuracy: 0.9515 - val_auc_5: 0.9864 - lr: 0.0012
# Epoch 93/100
# 618/618 - 4s - loss: 0.1146 - accuracy: 0.9538 - auc_5: 0.9889 - val_loss: 0.1253 - val_accuracy: 0.9517 - val_auc_5: 0.9865 - lr: 0.0011
# Epoch 94/100
# 618/618 - 4s - loss: 0.1138 - accuracy: 0.9545 - auc_5: 0.9889 - val_loss: 0.1251 - val_accuracy: 0.9520 - val_auc_5: 0.9865 - lr: 0.0011
# Epoch 95/100
# 618/618 - 3s - loss: 0.1147 - accuracy: 0.9543 - auc_5: 0.9889 - val_loss: 0.1256 - val_accuracy: 0.9515 - val_auc_5: 0.9865 - lr: 0.0011
# Epoch 96/100
# 618/618 - 3s - loss: 0.1150 - accuracy: 0.9538 - auc_5: 0.9887 - val_loss: 0.1256 - val_accuracy: 0.9519 - val_auc_5: 0.9866 - lr: 0.0010
# Epoch 97/100
# 618/618 - 3s - loss: 0.1139 - accuracy: 0.9544 - auc_5: 0.9889 - val_loss: 0.1261 - val_accuracy: 0.9518 - val_auc_5: 0.9864 - lr: 9.8583e-04
# Epoch 98/100
# 618/618 - 3s - loss: 0.1146 - accuracy: 0.9534 - auc_5: 0.9888 - val_loss: 0.1258 - val_accuracy: 0.9524 - val_auc_5: 0.9866 - lr: 9.5193e-04
# Epoch 99/100
# 618/618 - 4s - loss: 0.1146 - accuracy: 0.9537 - auc_5: 0.9889 - val_loss: 0.1256 - val_accuracy: 0.9517 - val_auc_5: 0.9866 - lr: 9.1919e-04
# Epoch 100/100
# 618/618 - 3s - loss: 0.1137 - accuracy: 0.9542 - auc_5: 0.9889 - val_loss: 0.1253 - val_accuracy: 0.9522 - val_auc_5: 0.9866 - lr: 8.8757e-04
#
#
# Time to train the neural network: 357.38962054252625

# %%
model.load_weights('best_epoch_constant')

# %%
test_loss, test_acc, test_auc = model.evaluate(X_test, Y_test_nc, verbose=1)
print('\nTest loss:', test_loss)
print('\nTest accuracy:', test_acc)
print('\nTest auc:', test_auc)
# Out:
# 772/772 [==============================] - 2s 3ms/step - loss: 0.1249 - accuracy: 0.9515 - auc_5: 0.9867
#
# Test loss: 0.12486758083105087
#
# Test accuracy: 0.9514901041984558
#
# Test auc: 0.9867414236068726

# %% [markdown]
# La loss e l'accuracy raggiungono valori soddisfacenti, soprattutto se comparati a quelli ottenuti tramite i Boosted Decision Trees. \\
# In media, si ottiene un'accuracy che oscilla, a seconda della run, tra il $95\%$ e il $95.3\%$. Ulteriore riprova della bontà della rete e la AUC, stabilmente a 0.987. \\
# Il tempo computazionale per ottenere tali valori risulta inoltre decisamente minore rispetto al tempo impiegato dagli algoritmi di Boosting. \\
# Di seguito si plottano la loss e l'accuracy per mostrarne l'andamento più dettagliatamente.

# %%
#plot della loss e della accuracy durante il training
plt.close()
plt.figure(figsize=(18, 6))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
max_acc = np.amax(acc)
max_val_acc = np.amax(val_acc)

loss=history.history['loss']
val_loss=history.history['val_loss']
min_loss = np.amin(loss)
min_val_loss = np.amin(val_loss)

auc_in = history.history['auc']
val_auc = history.history['val_auc']
max_auc = np.amax(auc_in)
max_val_auc = np.amax(val_auc)

epochs_range = range(1, len(loss) + 1)

plt.subplot(1, 3, 1)
plt.plot(epochs_range, loss, label='Training Loss, min = %.3f'%min_loss)
plt.plot(epochs_range, val_loss, label='Validation Loss, min = %.3f'%min_val_loss)
plt.legend(loc='upper right')
plt.ylim(0.1,0.22)
plt.title('Training and Validation Loss')

plt.subplot(1, 3, 2)
plt.plot(epochs_range, acc, label='Training Accuracy, max = %.3f'%max_acc)
plt.plot(epochs_range, val_acc, label='Validation Accuracy, max = %.3f'%max_val_acc)
plt.legend(loc='lower right')
plt.ylim(0.90,0.96)
plt.title('Training and Validation Accuracy')

plt.subplot(1, 3, 3)
plt.plot(epochs_range, auc_in, label='Training AUC, max = %.3f'%max_auc)
plt.plot(epochs_range, val_auc, label='Validation AUC, max = %.3f'%max_val_auc)
plt.legend(loc='lower right')
plt.ylim(0.96,0.995)
plt.title('Training and Validation Area Under Curve')
plt.show()

# %% [markdown]
# E' particolarmente interessante notare come, nonostante inizialmente le curve di validation risultino poco smooth a causa probabilmente del learning rate elevato, grazie all'espressione utilizzata per il decadimento giungono al loro valore asintotico attorno alle 60 epoche. Dalla funzione di loss del training si nota come un aumento di epoche avrebbe probabilmente condotto inesorabilmente ad un overfitting, più che ad un vero e proprio miglioramento della capacità di classificazione.

# %% [markdown]
# Si prova ora ad includere gli outliers per un confronto di prestazione.

# %%
#Splitting
train_to_test_ratio=0.8

X_train_out,X_test_out,Y_train_nc_out,Y_test_nc_out=train_test_split(data_out,labels_out,train_size=train_to_test_ratio)
#Y_train_out = keras.utils.to_categorical(Y_train_nc_out)
#Y_test_out = keras.utils.to_categorical(Y_test_nc_out)
print(X_train_out.shape)
print(X_test_out.shape)
print(Y_train_nc_out.shape)
print(Y_test_nc_out.shape)
# Out:
# (104051, 50)
# (26013, 50)
# (104051,)
# (26013,)

# %%
LR_ST=(1e-2)*2

OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=LR_ST)
model = create_model()
EAGERLY = False
auc = keras.metrics.AUC()

model.compile(optimizer=OPTIMIZER,
              loss='binary_crossentropy',
              metrics=['accuracy', auc],
              run_eagerly=EAGERLY)

# %%
lr_scheduler = keras.callbacks.LearningRateScheduler(lr_decay)
model_checkpoint = keras.callbacks.ModelCheckpoint(
        filepath = 'best_epoch_outliers',
        verbose = 0,
        save_weights_only = True, 
        save_freq = 'epoch',
        save_best_only = True,
        mode ='min')

callbacks = [ lr_scheduler, model_checkpoint ]

start_time = time.time()

history_out = model.fit(X_train_out, Y_train_nc_out, epochs=100, batch_size=128,
                    validation_split=0.2, shuffle=True, verbose=2,
                    callbacks=callbacks)

print("\n\nTime to train the neural network:", time.time()-start_time)
# Out:
# Epoch 1/100
# 651/651 - 4s - loss: 0.3064 - accuracy: 0.8685 - auc_3: 0.9276 - val_loss: 0.5902 - val_accuracy: 0.8460 - val_auc_3: 0.9104 - lr: 0.0200
# Epoch 2/100
# 651/651 - 4s - loss: 0.2793 - accuracy: 0.8804 - auc_3: 0.9399 - val_loss: 0.5931 - val_accuracy: 0.7973 - val_auc_3: 0.8880 - lr: 0.0200
# Epoch 3/100
# 651/651 - 4s - loss: 0.2690 - accuracy: 0.8852 - auc_3: 0.9444 - val_loss: 0.6493 - val_accuracy: 0.7570 - val_auc_3: 0.8985 - lr: 0.0200
# Epoch 4/100
# 651/651 - 4s - loss: 0.2667 - accuracy: 0.8865 - auc_3: 0.9452 - val_loss: 0.6214 - val_accuracy: 0.7209 - val_auc_3: 0.8714 - lr: 0.0200
# Epoch 5/100
# 651/651 - 4s - loss: 0.2588 - accuracy: 0.8903 - auc_3: 0.9485 - val_loss: 0.4863 - val_accuracy: 0.7497 - val_auc_3: 0.9188 - lr: 0.0200
# Epoch 6/100
# 651/651 - 4s - loss: 0.2558 - accuracy: 0.8932 - auc_3: 0.9497 - val_loss: 0.6593 - val_accuracy: 0.5406 - val_auc_3: 0.8842 - lr: 0.0200
# Epoch 7/100
# 651/651 - 4s - loss: 0.2488 - accuracy: 0.8957 - auc_3: 0.9526 - val_loss: 0.5121 - val_accuracy: 0.7446 - val_auc_3: 0.8815 - lr: 0.0200
# Epoch 8/100
# 651/651 - 4s - loss: 0.2429 - accuracy: 0.8986 - auc_3: 0.9546 - val_loss: 0.6360 - val_accuracy: 0.7189 - val_auc_3: 0.8643 - lr: 0.0200
# Epoch 9/100
# 651/651 - 4s - loss: 0.2385 - accuracy: 0.8998 - auc_3: 0.9563 - val_loss: 0.5082 - val_accuracy: 0.7423 - val_auc_3: 0.8803 - lr: 0.0200
# Epoch 10/100
# 651/651 - 4s - loss: 0.2379 - accuracy: 0.8996 - auc_3: 0.9565 - val_loss: 0.8590 - val_accuracy: 0.7183 - val_auc_3: 0.8402 - lr: 0.0200
# Epoch 11/100
# 651/651 - 4s - loss: 0.2331 - accuracy: 0.9031 - auc_3: 0.9583 - val_loss: 1.0914 - val_accuracy: 0.7153 - val_auc_3: 0.8069 - lr: 0.0200
# Epoch 12/100
# 651/651 - 4s - loss: 0.2326 - accuracy: 0.9028 - auc_3: 0.9584 - val_loss: 0.4221 - val_accuracy: 0.7881 - val_auc_3: 0.9220 - lr: 0.0193
# Epoch 13/100
# 651/651 - 4s - loss: 0.2294 - accuracy: 0.9042 - auc_3: 0.9596 - val_loss: 0.6499 - val_accuracy: 0.7284 - val_auc_3: 0.8689 - lr: 0.0186
# Epoch 14/100
# 651/651 - 4s - loss: 0.2281 - accuracy: 0.9049 - auc_3: 0.9601 - val_loss: 0.8736 - val_accuracy: 0.7252 - val_auc_3: 0.8270 - lr: 0.0180
# Epoch 15/100
# 651/651 - 4s - loss: 0.2240 - accuracy: 0.9071 - auc_3: 0.9614 - val_loss: 0.7146 - val_accuracy: 0.7334 - val_auc_3: 0.8608 - lr: 0.0174
# Epoch 16/100
# 651/651 - 4s - loss: 0.2217 - accuracy: 0.9080 - auc_3: 0.9623 - val_loss: 1.4307 - val_accuracy: 0.7147 - val_auc_3: 0.7334 - lr: 0.0168
# Epoch 17/100
# 651/651 - 4s - loss: 0.2185 - accuracy: 0.9101 - auc_3: 0.9632 - val_loss: 0.7136 - val_accuracy: 0.7392 - val_auc_3: 0.8751 - lr: 0.0162
# Epoch 18/100
# 651/651 - 4s - loss: 0.2179 - accuracy: 0.9102 - auc_3: 0.9635 - val_loss: 0.4671 - val_accuracy: 0.7629 - val_auc_3: 0.8837 - lr: 0.0157
# Epoch 19/100
# 651/651 - 4s - loss: 0.2175 - accuracy: 0.9112 - auc_3: 0.9635 - val_loss: 0.5088 - val_accuracy: 0.7574 - val_auc_3: 0.8712 - lr: 0.0151
# Epoch 20/100
# 651/651 - 4s - loss: 0.2134 - accuracy: 0.9116 - auc_3: 0.9651 - val_loss: 0.5663 - val_accuracy: 0.7332 - val_auc_3: 0.7917 - lr: 0.0146
# Epoch 21/100
# 651/651 - 4s - loss: 0.2123 - accuracy: 0.9126 - auc_3: 0.9654 - val_loss: 0.8748 - val_accuracy: 0.7158 - val_auc_3: 0.7587 - lr: 0.0141
# Epoch 22/100
# 651/651 - 4s - loss: 0.2109 - accuracy: 0.9133 - auc_3: 0.9659 - val_loss: 0.6500 - val_accuracy: 0.7421 - val_auc_3: 0.8122 - lr: 0.0136
# Epoch 23/100
# 651/651 - 4s - loss: 0.2095 - accuracy: 0.9132 - auc_3: 0.9661 - val_loss: 0.7453 - val_accuracy: 0.7180 - val_auc_3: 0.8740 - lr: 0.0131
# Epoch 24/100
# 651/651 - 4s - loss: 0.2069 - accuracy: 0.9146 - auc_3: 0.9671 - val_loss: 0.7186 - val_accuracy: 0.7332 - val_auc_3: 0.8316 - lr: 0.0127
# Epoch 25/100
# 651/651 - 4s - loss: 0.2046 - accuracy: 0.9152 - auc_3: 0.9677 - val_loss: 0.7261 - val_accuracy: 0.7172 - val_auc_3: 0.8852 - lr: 0.0123
# Epoch 26/100
# 651/651 - 4s - loss: 0.2036 - accuracy: 0.9164 - auc_3: 0.9680 - val_loss: 0.8423 - val_accuracy: 0.7183 - val_auc_3: 0.9014 - lr: 0.0118
# Epoch 27/100
# 651/651 - 4s - loss: 0.2043 - accuracy: 0.9164 - auc_3: 0.9678 - val_loss: 1.3059 - val_accuracy: 0.7152 - val_auc_3: 0.8093 - lr: 0.0114
# Epoch 28/100
# 651/651 - 4s - loss: 0.2022 - accuracy: 0.9170 - auc_3: 0.9685 - val_loss: 0.6352 - val_accuracy: 0.7477 - val_auc_3: 0.9125 - lr: 0.0110
# Epoch 29/100
# 651/651 - 4s - loss: 0.2004 - accuracy: 0.9170 - auc_3: 0.9690 - val_loss: 0.6363 - val_accuracy: 0.7442 - val_auc_3: 0.8810 - lr: 0.0107
# Epoch 30/100
# 651/651 - 4s - loss: 0.2009 - accuracy: 0.9178 - auc_3: 0.9688 - val_loss: 0.7063 - val_accuracy: 0.7181 - val_auc_3: 0.8632 - lr: 0.0103
# Epoch 31/100
# 651/651 - 4s - loss: 0.1979 - accuracy: 0.9187 - auc_3: 0.9698 - val_loss: 1.0163 - val_accuracy: 0.7226 - val_auc_3: 0.8474 - lr: 0.0099
# Epoch 32/100
# 651/651 - 4s - loss: 0.1982 - accuracy: 0.9190 - auc_3: 0.9696 - val_loss: 0.3891 - val_accuracy: 0.8121 - val_auc_3: 0.9169 - lr: 0.0096
# Epoch 33/100
# 651/651 - 4s - loss: 0.1989 - accuracy: 0.9179 - auc_3: 0.9695 - val_loss: 0.6620 - val_accuracy: 0.7264 - val_auc_3: 0.8764 - lr: 0.0093
# Epoch 34/100
# 651/651 - 4s - loss: 0.1970 - accuracy: 0.9191 - auc_3: 0.9699 - val_loss: 0.6896 - val_accuracy: 0.7242 - val_auc_3: 0.9317 - lr: 0.0089
# Epoch 35/100
# 651/651 - 4s - loss: 0.1954 - accuracy: 0.9193 - auc_3: 0.9704 - val_loss: 1.0002 - val_accuracy: 0.7164 - val_auc_3: 0.8745 - lr: 0.0086
# Epoch 36/100
# 651/651 - 4s - loss: 0.1957 - accuracy: 0.9211 - auc_3: 0.9703 - val_loss: 1.0772 - val_accuracy: 0.7195 - val_auc_3: 0.8384 - lr: 0.0083
# Epoch 37/100
# 651/651 - 4s - loss: 0.1943 - accuracy: 0.9204 - auc_3: 0.9708 - val_loss: 0.5211 - val_accuracy: 0.7483 - val_auc_3: 0.9003 - lr: 0.0081
# Epoch 38/100
# 651/651 - 4s - loss: 0.1950 - accuracy: 0.9204 - auc_3: 0.9706 - val_loss: 0.6419 - val_accuracy: 0.7480 - val_auc_3: 0.9114 - lr: 0.0078
# Epoch 39/100
# 651/651 - 4s - loss: 0.1936 - accuracy: 0.9209 - auc_3: 0.9709 - val_loss: 0.8540 - val_accuracy: 0.7203 - val_auc_3: 0.9183 - lr: 0.0075
# Epoch 40/100
# 651/651 - 4s - loss: 0.1916 - accuracy: 0.9222 - auc_3: 0.9716 - val_loss: 0.4307 - val_accuracy: 0.7996 - val_auc_3: 0.9169 - lr: 0.0072
# Epoch 41/100
# 651/651 - 4s - loss: 0.1909 - accuracy: 0.9226 - auc_3: 0.9718 - val_loss: 0.4201 - val_accuracy: 0.7951 - val_auc_3: 0.9500 - lr: 0.0070
# Epoch 42/100
# 651/651 - 4s - loss: 0.1882 - accuracy: 0.9234 - auc_3: 0.9726 - val_loss: 0.9417 - val_accuracy: 0.7243 - val_auc_3: 0.8495 - lr: 0.0068
# Epoch 43/100
# 651/651 - 4s - loss: 0.1887 - accuracy: 0.9235 - auc_3: 0.9724 - val_loss: 0.3710 - val_accuracy: 0.8516 - val_auc_3: 0.9177 - lr: 0.0065
# Epoch 44/100
# 651/651 - 4s - loss: 0.1876 - accuracy: 0.9244 - auc_3: 0.9726 - val_loss: 0.9100 - val_accuracy: 0.7187 - val_auc_3: 0.9326 - lr: 0.0063
# Epoch 45/100
# 651/651 - 4s - loss: 0.1882 - accuracy: 0.9241 - auc_3: 0.9725 - val_loss: 0.7056 - val_accuracy: 0.7429 - val_auc_3: 0.9440 - lr: 0.0061
# Epoch 46/100
# 651/651 - 4s - loss: 0.1870 - accuracy: 0.9242 - auc_3: 0.9728 - val_loss: 0.8015 - val_accuracy: 0.7299 - val_auc_3: 0.9062 - lr: 0.0059
# Epoch 47/100
# 651/651 - 4s - loss: 0.1853 - accuracy: 0.9239 - auc_3: 0.9734 - val_loss: 0.5323 - val_accuracy: 0.7476 - val_auc_3: 0.9264 - lr: 0.0057
# Epoch 48/100
# 651/651 - 4s - loss: 0.1852 - accuracy: 0.9246 - auc_3: 0.9734 - val_loss: 0.2666 - val_accuracy: 0.8790 - val_auc_3: 0.9552 - lr: 0.0055
# Epoch 49/100
# 651/651 - 4s - loss: 0.1836 - accuracy: 0.9259 - auc_3: 0.9739 - val_loss: 0.6461 - val_accuracy: 0.7417 - val_auc_3: 0.9302 - lr: 0.0053
# Epoch 50/100
# 651/651 - 4s - loss: 0.1816 - accuracy: 0.9265 - auc_3: 0.9744 - val_loss: 0.6955 - val_accuracy: 0.7427 - val_auc_3: 0.9278 - lr: 0.0051
# Epoch 51/100
# 651/651 - 4s - loss: 0.1822 - accuracy: 0.9267 - auc_3: 0.9742 - val_loss: 0.6077 - val_accuracy: 0.7418 - val_auc_3: 0.9318 - lr: 0.0049
# Epoch 52/100
# 651/651 - 4s - loss: 0.1809 - accuracy: 0.9260 - auc_3: 0.9747 - val_loss: 0.7196 - val_accuracy: 0.7276 - val_auc_3: 0.9266 - lr: 0.0048
# Epoch 53/100
# 651/651 - 4s - loss: 0.1825 - accuracy: 0.9262 - auc_3: 0.9742 - val_loss: 0.5771 - val_accuracy: 0.7472 - val_auc_3: 0.9606 - lr: 0.0046
# Epoch 54/100
# 651/651 - 4s - loss: 0.1816 - accuracy: 0.9266 - auc_3: 0.9744 - val_loss: 0.4578 - val_accuracy: 0.7843 - val_auc_3: 0.9300 - lr: 0.0044
# Epoch 55/100
# 651/651 - 4s - loss: 0.1801 - accuracy: 0.9272 - auc_3: 0.9749 - val_loss: 0.9677 - val_accuracy: 0.7222 - val_auc_3: 0.9212 - lr: 0.0043
# Epoch 56/100
# 651/651 - 4s - loss: 0.1792 - accuracy: 0.9280 - auc_3: 0.9751 - val_loss: 0.4889 - val_accuracy: 0.7926 - val_auc_3: 0.9476 - lr: 0.0041
# Epoch 57/100
# 651/651 - 4s - loss: 0.1776 - accuracy: 0.9283 - auc_3: 0.9755 - val_loss: 0.4259 - val_accuracy: 0.7757 - val_auc_3: 0.9603 - lr: 0.0040
# Epoch 58/100
# 651/651 - 4s - loss: 0.1780 - accuracy: 0.9280 - auc_3: 0.9753 - val_loss: 0.5957 - val_accuracy: 0.7601 - val_auc_3: 0.9431 - lr: 0.0039
# Epoch 59/100
# 651/651 - 4s - loss: 0.1777 - accuracy: 0.9275 - auc_3: 0.9754 - val_loss: 0.8540 - val_accuracy: 0.7272 - val_auc_3: 0.9155 - lr: 0.0037
# Epoch 60/100
# 651/651 - 4s - loss: 0.1789 - accuracy: 0.9282 - auc_3: 0.9750 - val_loss: 0.3765 - val_accuracy: 0.7988 - val_auc_3: 0.9496 - lr: 0.0036
# Epoch 61/100
# 651/651 - 4s - loss: 0.1765 - accuracy: 0.9285 - auc_3: 0.9757 - val_loss: 0.6526 - val_accuracy: 0.7301 - val_auc_3: 0.9498 - lr: 0.0035
# Epoch 62/100
# 651/651 - 4s - loss: 0.1768 - accuracy: 0.9280 - auc_3: 0.9757 - val_loss: 0.4009 - val_accuracy: 0.8072 - val_auc_3: 0.9688 - lr: 0.0034
# Epoch 63/100
# 651/651 - 4s - loss: 0.1760 - accuracy: 0.9291 - auc_3: 0.9759 - val_loss: 0.5851 - val_accuracy: 0.7550 - val_auc_3: 0.9218 - lr: 0.0032
# Epoch 64/100
# 651/651 - 4s - loss: 0.1757 - accuracy: 0.9285 - auc_3: 0.9762 - val_loss: 0.6755 - val_accuracy: 0.7443 - val_auc_3: 0.9496 - lr: 0.0031
# Epoch 65/100
# 651/651 - 4s - loss: 0.1767 - accuracy: 0.9290 - auc_3: 0.9756 - val_loss: 0.3811 - val_accuracy: 0.7903 - val_auc_3: 0.9656 - lr: 0.0030
# Epoch 66/100
# 651/651 - 4s - loss: 0.1740 - accuracy: 0.9301 - auc_3: 0.9763 - val_loss: 0.3954 - val_accuracy: 0.8089 - val_auc_3: 0.9593 - lr: 0.0029
# Epoch 67/100
# 651/651 - 4s - loss: 0.1748 - accuracy: 0.9294 - auc_3: 0.9762 - val_loss: 1.0003 - val_accuracy: 0.7212 - val_auc_3: 0.8983 - lr: 0.0028
# Epoch 68/100
# 651/651 - 4s - loss: 0.1755 - accuracy: 0.9293 - auc_3: 0.9760 - val_loss: 0.3226 - val_accuracy: 0.8271 - val_auc_3: 0.9687 - lr: 0.0027
# Epoch 69/100
# 651/651 - 4s - loss: 0.1764 - accuracy: 0.9289 - auc_3: 0.9757 - val_loss: 0.4064 - val_accuracy: 0.7725 - val_auc_3: 0.9692 - lr: 0.0026
# Epoch 70/100
# 651/651 - 4s - loss: 0.1746 - accuracy: 0.9293 - auc_3: 0.9763 - val_loss: 0.9315 - val_accuracy: 0.7226 - val_auc_3: 0.9023 - lr: 0.0025
# Epoch 71/100
# 651/651 - 4s - loss: 0.1734 - accuracy: 0.9288 - auc_3: 0.9766 - val_loss: 0.3930 - val_accuracy: 0.7948 - val_auc_3: 0.9500 - lr: 0.0024
# Epoch 72/100
# 651/651 - 4s - loss: 0.1742 - accuracy: 0.9305 - auc_3: 0.9763 - val_loss: 0.2164 - val_accuracy: 0.9036 - val_auc_3: 0.9776 - lr: 0.0024
# Epoch 73/100
# 651/651 - 4s - loss: 0.1746 - accuracy: 0.9299 - auc_3: 0.9764 - val_loss: 0.3685 - val_accuracy: 0.8128 - val_auc_3: 0.9572 - lr: 0.0023
# Epoch 74/100
# 651/651 - 4s - loss: 0.1739 - accuracy: 0.9292 - auc_3: 0.9766 - val_loss: 0.5822 - val_accuracy: 0.7495 - val_auc_3: 0.9561 - lr: 0.0022
# Epoch 75/100
# 651/651 - 4s - loss: 0.1720 - accuracy: 0.9311 - auc_3: 0.9770 - val_loss: 0.2550 - val_accuracy: 0.8835 - val_auc_3: 0.9620 - lr: 0.0021
# Epoch 76/100
# 651/651 - 4s - loss: 0.1727 - accuracy: 0.9302 - auc_3: 0.9768 - val_loss: 0.5906 - val_accuracy: 0.7648 - val_auc_3: 0.9379 - lr: 0.0021
# Epoch 77/100
# 651/651 - 4s - loss: 0.1729 - accuracy: 0.9310 - auc_3: 0.9766 - val_loss: 0.4061 - val_accuracy: 0.7959 - val_auc_3: 0.9633 - lr: 0.0020
# Epoch 78/100
# 651/651 - 4s - loss: 0.1730 - accuracy: 0.9296 - auc_3: 0.9767 - val_loss: 0.4506 - val_accuracy: 0.7831 - val_auc_3: 0.9673 - lr: 0.0019
# Epoch 79/100
# 651/651 - 4s - loss: 0.1712 - accuracy: 0.9309 - auc_3: 0.9771 - val_loss: 0.2280 - val_accuracy: 0.8924 - val_auc_3: 0.9762 - lr: 0.0019
# Epoch 80/100
# 651/651 - 4s - loss: 0.1708 - accuracy: 0.9314 - auc_3: 0.9774 - val_loss: 0.4216 - val_accuracy: 0.7906 - val_auc_3: 0.9666 - lr: 0.0018
# Epoch 81/100
# 651/651 - 4s - loss: 0.1698 - accuracy: 0.9309 - auc_3: 0.9776 - val_loss: 0.1930 - val_accuracy: 0.9215 - val_auc_3: 0.9751 - lr: 0.0017
# Epoch 82/100
# 651/651 - 4s - loss: 0.1714 - accuracy: 0.9315 - auc_3: 0.9771 - val_loss: 0.2762 - val_accuracy: 0.8565 - val_auc_3: 0.9766 - lr: 0.0017
# Epoch 83/100
# 651/651 - 4s - loss: 0.1713 - accuracy: 0.9317 - auc_3: 0.9771 - val_loss: 0.5419 - val_accuracy: 0.7704 - val_auc_3: 0.9575 - lr: 0.0016
# Epoch 84/100
# 651/651 - 4s - loss: 0.1705 - accuracy: 0.9314 - auc_3: 0.9775 - val_loss: 0.3648 - val_accuracy: 0.8058 - val_auc_3: 0.9726 - lr: 0.0016
# Epoch 85/100
# 651/651 - 4s - loss: 0.1705 - accuracy: 0.9310 - auc_3: 0.9774 - val_loss: 0.4186 - val_accuracy: 0.7973 - val_auc_3: 0.9628 - lr: 0.0015
# Epoch 86/100
# 651/651 - 4s - loss: 0.1703 - accuracy: 0.9315 - auc_3: 0.9774 - val_loss: 0.2022 - val_accuracy: 0.9136 - val_auc_3: 0.9796 - lr: 0.0014
# Epoch 87/100
# 651/651 - 4s - loss: 0.1713 - accuracy: 0.9304 - auc_3: 0.9772 - val_loss: 0.4304 - val_accuracy: 0.7923 - val_auc_3: 0.9662 - lr: 0.0014
# Epoch 88/100
# 651/651 - 4s - loss: 0.1699 - accuracy: 0.9318 - auc_3: 0.9775 - val_loss: 0.2929 - val_accuracy: 0.8584 - val_auc_3: 0.9713 - lr: 0.0014
# Epoch 89/100
# 651/651 - 4s - loss: 0.1696 - accuracy: 0.9316 - auc_3: 0.9778 - val_loss: 0.3701 - val_accuracy: 0.8174 - val_auc_3: 0.9689 - lr: 0.0013
# Epoch 90/100
# 651/651 - 4s - loss: 0.1694 - accuracy: 0.9313 - auc_3: 0.9777 - val_loss: 0.4091 - val_accuracy: 0.8012 - val_auc_3: 0.9690 - lr: 0.0013
# Epoch 91/100
# 651/651 - 4s - loss: 0.1699 - accuracy: 0.9310 - auc_3: 0.9775 - val_loss: 0.3153 - val_accuracy: 0.8543 - val_auc_3: 0.9695 - lr: 0.0012
# Epoch 92/100
# 651/651 - 4s - loss: 0.1701 - accuracy: 0.9317 - auc_3: 0.9775 - val_loss: 0.2137 - val_accuracy: 0.9059 - val_auc_3: 0.9769 - lr: 0.0012
# Epoch 93/100
# 651/651 - 4s - loss: 0.1689 - accuracy: 0.9320 - auc_3: 0.9777 - val_loss: 0.2229 - val_accuracy: 0.8961 - val_auc_3: 0.9777 - lr: 0.0011
# Epoch 94/100
# 651/651 - 4s - loss: 0.1691 - accuracy: 0.9319 - auc_3: 0.9778 - val_loss: 0.4612 - val_accuracy: 0.7813 - val_auc_3: 0.9695 - lr: 0.0011
# Epoch 95/100
# 651/651 - 4s - loss: 0.1692 - accuracy: 0.9314 - auc_3: 0.9778 - val_loss: 0.3976 - val_accuracy: 0.8019 - val_auc_3: 0.9714 - lr: 0.0011
# Epoch 96/100
# 651/651 - 4s - loss: 0.1683 - accuracy: 0.9318 - auc_3: 0.9779 - val_loss: 0.2351 - val_accuracy: 0.8884 - val_auc_3: 0.9776 - lr: 0.0010
# Epoch 97/100
# 651/651 - 4s - loss: 0.1694 - accuracy: 0.9314 - auc_3: 0.9776 - val_loss: 0.3118 - val_accuracy: 0.8468 - val_auc_3: 0.9729 - lr: 9.8583e-04
# Epoch 98/100
# 651/651 - 4s - loss: 0.1677 - accuracy: 0.9324 - auc_3: 0.9781 - val_loss: 0.2241 - val_accuracy: 0.8964 - val_auc_3: 0.9777 - lr: 9.5193e-04
# Epoch 99/100
# 651/651 - 4s - loss: 0.1689 - accuracy: 0.9326 - auc_3: 0.9778 - val_loss: 0.2598 - val_accuracy: 0.8742 - val_auc_3: 0.9750 - lr: 9.1919e-04
# Epoch 100/100
# 651/651 - 4s - loss: 0.1693 - accuracy: 0.9320 - auc_3: 0.9776 - val_loss: 0.3077 - val_accuracy: 0.8466 - val_auc_3: 0.9735 - lr: 8.8757e-04
#
#
# Time to train the neural network: 366.7842261791229

# %%
model.load_weights('best_epoch_outliers')

# %%
test_loss, test_acc, test_auc = model.evaluate(X_test_out, Y_test_nc_out, verbose=1)
print('\nTest loss:', test_loss)
print('\nTest accuracy:', test_acc)
print('\nTest auc:', test_auc)
# Out:
# 813/813 [==============================] - 2s 3ms/step - loss: 0.1943 - accuracy: 0.9217 - auc_3: 0.9738
#
# Test loss: 0.19433990120887756
#
# Test accuracy: 0.9216545820236206
#
# Test auc: 0.9737746715545654

# %%
#plot della loss e della accuracy durante il training
plt.close()
plt.figure(figsize=(18, 6))
acc_out = history_out.history['accuracy']
val_acc_out = history_out.history['val_accuracy']
max_acc_out = np.amax(acc_out)
max_val_acc_out = np.amax(val_acc_out)

loss_out=history_out.history['loss']
val_loss_out=history_out.history['val_loss']
min_loss_out = np.amin(loss_out)
min_val_loss_out = np.amin(val_loss_out)

auc_out = history_out.history['auc_3']
val_auc_out = history_out.history['val_auc_3']
max_auc_out = np.amax(auc_out)
max_val_auc_out = np.amax(val_auc_out)

epochs_range = range(1, len(loss) + 1)

plt.subplot(1, 3, 1)
plt.plot(epochs_range, loss_out, label='Training Loss, min = %.3f'%min_loss_out)
plt.plot(epochs_range, val_loss_out, label='Validation Loss, min = %.3f'%min_val_loss_out)
plt.legend(loc='upper right')
plt.ylim(0.05,1.5)
plt.title('Training and Validation Loss')

plt.subplot(1, 3, 2)
plt.plot(epochs_range, acc_out, label='Training Accuracy, max = %.3f'%max_acc_out)
plt.plot(epochs_range, val_acc_out, label='Validation Accuracy, max = %.3f'%max_val_acc_out)
plt.legend(loc='lower right')
plt.ylim(0.5,1)
plt.title('Training and Validation Accuracy')

plt.subplot(1, 3, 3)
plt.plot(epochs_range, auc_out, label='Training AUC, max = %.3f'%max_auc_out)
plt.plot(epochs_range, val_auc_out, label='Validation AUC, max = %.3f'%max_val_auc_out)
plt.legend(loc='lower right')
plt.ylim(0.73,1.)
plt.title('Training and Validation Area Under Curve')
plt.show()

# %% [markdown]
# Si nota come l'addestramento di una rete con dati comprensivi di outliers riduca sensibilmente le prestazioni. \\
# Per un'ulteriore chiarezza si mettono a confronto sul medesimo grafico gli andamenti delle tre curve con e senza outliers:

# %%
#plot della loss e della accuracy durante il training
plt.close()
plt.figure(figsize=(18, 6))
epochs_range = range(1, len(loss) + 1)

plt.subplot(1, 3, 1)
plt.plot(epochs_range, loss, label='Training Loss, no out, min = %.3f'%min_loss)
plt.plot(epochs_range, val_loss, label='Validation Loss, no out, min = %.3f'%min_val_loss)
plt.plot(epochs_range, loss_out, label='Training Loss, out, min = %.3f'%min_loss_out)
plt.plot(epochs_range, val_loss_out, label='Validation Loss, out, min = %.3f'%min_val_loss_out)
plt.legend(loc='upper right')
plt.ylim(0.05,1.67)
plt.title('Training and Validation Loss')

plt.subplot(1, 3, 2)
plt.plot(epochs_range, acc, label='Training Accuracy, no out, max = %.3f'%max_acc)
plt.plot(epochs_range, val_acc, label='Validation Accuracy, no out, max = %.3f'%max_val_acc)
plt.plot(epochs_range, acc_out, label='Training Accuracy, out, max = %.3f'%max_acc_out)
plt.plot(epochs_range, val_acc_out, label='Validation Accuracy, out, max = %.3f'%max_val_acc_out)
plt.legend(loc='lower right')
plt.ylim(0.5,1)
plt.title('Training and Validation Accuracy')

plt.subplot(1, 3, 3)
plt.plot(epochs_range, auc_in, label='Training AUC, no out, max = %.3f'%max_auc)
plt.plot(epochs_range, val_auc, label='Validation AUC, no out, max = %.3f'%max_val_auc)
plt.plot(epochs_range, auc_out, label='Training AUC, out, max = %.3f'%max_auc_out)
plt.plot(epochs_range, val_auc_out, label='Validation AUC, out, max = %.3f'%max_val_auc_out)
plt.legend(loc='lower right')
plt.ylim(0.7,1.)
plt.title('Training and Validation Area Under Curve')
plt.show()

# %% [markdown]
# Si evince facilmente come la funzione di validation comprensiva di outliers sia altamente instabile e come i migliori risultati si ottengano con il dataset privato degli outliers.
